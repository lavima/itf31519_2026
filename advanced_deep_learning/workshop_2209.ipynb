# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import OrdinalEncoder, TargetEncoder, Normalizer

# %%
dataset = pd.read_csv('../data/life_expectancy/Life Expectancy Data.csv')
dataset.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   str
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   str
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), str(2)
# memory usage: 505.1 KB

# %%
# Exploratory Data Analysis (EDA)

# Distributions via histograms

dataset.hist()
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Life expectancy '}>,
#         <Axes: title={'center': 'Adult Mortality'}>,
#         <Axes: title={'center': 'infant deaths'}>],
#        [<Axes: title={'center': 'Alcohol'}>,
#         <Axes: title={'center': 'percentage expenditure'}>,
#         <Axes: title={'center': 'Hepatitis B'}>,
#         <Axes: title={'center': 'Measles '}>],
#        [<Axes: title={'center': ' BMI '}>,
#         <Axes: title={'center': 'under-five deaths '}>,
#         <Axes: title={'center': 'Polio'}>,
#         <Axes: title={'center': 'Total expenditure'}>],
#        [<Axes: title={'center': 'Diphtheria '}>,
#         <Axes: title={'center': ' HIV/AIDS'}>,
#         <Axes: title={'center': 'GDP'}>,
#         <Axes: title={'center': 'Population'}>],
#        [<Axes: title={'center': ' thinness  1-19 years'}>,
#         <Axes: title={'center': ' thinness 5-9 years'}>,
#         <Axes: title={'center': 'Income composition of resources'}>,
#         <Axes: title={'center': 'Schooling'}>]], dtype=object)

# %%
dataset['Status'].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   str
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   str
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), str(2)
# memory usage: 505.1 KB

# %%
# Encode categorical data with temporary encodings

dataset_temp = dataset.copy()
dataset_temp['Country'] = OrdinalEncoder().fit_transform(dataset_temp[['Country']])
dataset_temp['Status'] = dataset['Status'].replace({'Developing':0, 'Developed':1})
dataset_temp['Country'].value_counts()
dataset_temp['Status'].value_counts()

# Distributions of categorical data

# fig = plt.figure(figsize=(100, 1))
# dataset_temp['Status'].plot.bar()
sb.barplot(data=dataset['Status'])
# sb.barplot(x=dataset_temp['Country'])
# Out:
# <Axes: ylabel='Status'>

# %%
# Correlation
 
correlation = dataset.drop(['Country', 'Status'], axis=1).corr()
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_28117_row0_col0, #T_28117_row1_col1, #T_28117_row2_col2, #T_28117_row3_col3, #T_28117_row3_col9, #T_28117_row4_col4, #T_28117_row5_col5, #T_28117_row6_col6, #T_28117_row7_col7, #T_28117_row8_col8, #T_28117_row9_col3, #T_28117_row9_col9, #T_28117_row10_col10, #T_28117_row11_col11, #T_28117_row12_col12, #T_28117_row13_col13, #T_28117_row14_col14, #T_28117_row15_col15, #T_28117_row16_col16, #T_28117_row17_col17, #T_28117_row18_col18, #T_28117_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_28117_row0_col1, #T_28117_row11_col4 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_28117_row0_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T
col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_28117_row2_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_28117_row2_col7, #T_28117_row9_col19, #T_28117_row13_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_28117_row2_col8, #T_28117_row4_col9, #T_28117_row5_col7, #T_28117_row13_col6, #T_28117_row14_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_28117_row2_col11, #T_28117_row9_col5, #T_28117_row16_col1, #T_28117_row17_col1 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_28117_row2_col13, #T_28117_row4_col19, #T_28117_row8_col19, #T_28117_row12_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_28117_row2_col15, #T_28117_row14_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_28117_row2_col16, #T_28117_row14_col8, #T_28117_row19_col10 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_28117_row2_col17, #T_28117_row14_col4, #T_28117_row19_col12 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_28117_row3_col0, #T_28117_row5_col15, #T_28117_row11_col9, #T_28117_row13_col12, #T_28117_row15_col6, #T_28117_row17_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_28117_row3_col1, #T_28117_row4_col2, #T_28117_row5_col13, #T_28117_row6_col14 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_28117_row3_col2, #T_28117_row10_col4, #T_28117_row12_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_28117_row3_col4, #T_28117_row9_col4, #T_28117_row13_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_28117_row3_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_28117_row3_col6, #T_28117_row16_col8, #T_28117_row16_col11, #T_28117_row17_col14, #T_28117_row17_col19 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_28117_row3_col7, #T_28117_row5_col18, #T_28117_row10_col18, #T_28117_row19_col14 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_28117_row3_col8, #T_28117_row5_col6, #T_28117_row8_col13, #T_28117_row9_col18, #T_28117_row10_col16, #T_28117_row11_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_28117_row3_col11, #T_28117_row5_col9, #T_28117_row9_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_28117_row3_col13, #T_28117_row14_col12 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_28117_row3_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_28117_row3_col15, #T_28117_row7_col9, #T_28117_row10_col19 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_28117_row3_col16, #T_28117_row4_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_28117_row3_col17, #T_28117_row9_col17 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_28117_row3_col18, #T_28117_row6_col0, #T_28117_row6_col5, #T_28117_row14_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_28117_row3_col19 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_28117_row4_col0, #T_28117_row10_col15, #T_28117_row17_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_28117_row4_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_28117_row4_col6 {
#   background-color: #90b2fe

# %%
# Dimensionality compression

# %%
# Processing

# Remove missing values

dataset.dropna(inplace=True)

# Imput replacement data

# dataset.fillna(dataset.mean(), inplace=True)

# Encoding

dataset['Status'] = dataset['Status'].replace({'Developing':0, 'Developed':1})

# dataset.dropna(subset='Life expectancy ', inplace=True)
dataset['Country'] = TargetEncoder().fit_transform(dataset[['Country']], dataset['Life expectancy '])
dataset.Country.plot.hist()
# Alternativel use one hot encoding
# Out:
# <Axes: ylabel='Frequency'>

# %%
numerical_features = dataset.drop(['Country', 'Status'], axis=1).columns
numerical_features

# Mean normalization
dataset[numerical_features] = (dataset[numerical_features] - dataset[numerical_features].mean())/dataset[numerical_features].std()
# using sklearn
dataset[numerical_features] = Normalizer().fit_transform(dataset[numerical_features])

# %%
# We'll continue next week (Sorry)
